# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import jeet

# %%
df = pd.read_csv('Verrucodesmus_verrucosus.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Irradiance    1080 non-null   float64
#  1   NO3           1080 non-null   float64
#  2   Temperature   1080 non-null   float64
#  3   pH            1080 non-null   float64
#  4   Biomass       1080 non-null   float64
#  5   O2 Gas        1080 non-null   float64
#  6   CO2 Gas       1080 non-null   float64
#  7   OD            1080 non-null   float64
#  8   Conductivity  1080 non-null   float64
# dtypes: float64(9)
# memory usage: 76.1 KB

# %%
col_name = df.columns.to_list()

# %%
df.drop(columns=['OD'],inplace = True)

# %%
df.corr()
# Out:
#               Irradiance       NO3  Temperature        pH   Biomass    O2 Gas  \
# Irradiance      1.000000 -0.174535     0.025114  0.166195  0.191836 -0.183001
# NO3            -0.174535  1.000000    -0.330535 -0.676671 -0.965807  0.968829
# Temperature     0.025114 -0.330535     1.000000  0.250993  0.313292 -0.332235
# pH              0.166195 -0.676671     0.250993  1.000000  0.775954 -0.789878
# Biomass         0.191836 -0.965807     0.313292  0.775954  1.000000 -0.979098
# O2 Gas         -0.183001  0.968829    -0.332235 -0.789878 -0.979098  1.000000
# CO2 Gas        -0.174732  0.949233    -0.289477 -0.802959 -0.950950  0.959042
# Conductivity    0.141850 -0.839384     0.323342  0.573216  0.809424 -0.792746
#
#                CO2 Gas  Conductivity
# Irradiance   -0.174732      0.141850
# NO3           0.949233     -0.839384
# Temperature  -0.289477      0.323342
# pH           -0.802959      0.573216
# Biomass      -0.950950      0.809424
# O2 Gas        0.959042     -0.792746
# ...

# %%
jeet.CorrectionMap(df)

# %%
for element in col_name:
    jeet.ScatterPlot(df,'Biomass',element)

# %%
df.columns
# Out:
# Index(['Irradiance', 'NO3', 'Temperature', 'pH', 'Biomass', 'O2 Gas',
#        'CO2 Gas', 'OD', 'Conductivity'],
#       dtype='object')

# %%
jeet.Pairplot(df ,'Biomass', 'O2 Gas',
       'CO2 Gas' )

# %%
jeet.Pairplot(df ,'NO3', 'Temperature','Biomass')
